# %%
import argparse
import requests
from apiclient.discovery import build
import httplib2
from oauth2client import client
from oauth2client import file
from oauth2client import tools
from datetime import datetime, timedelta
import pandas as pd
import sqlalchemy 
import numpy as np

SCOPES = ['https://www.googleapis.com/auth/analytics.readonly']
DISCOVERY_URI = ('https://analyticsreporting.googleapis.com/$discovery/rest')
CLIENT_SECRETS_PATH = 'C:/Users/sachi/OneDrive/Desktop/Google_Analytics/client_secret_358050000476-cn1c98do5mg0e43jvvvh3fgpklkdqlhs.apps.googleusercontent.com.json' # Path to client_secrets.json file.
VIEW_ID = '63497244'


def initialize_analyticsreporting():
  
  
  parser = argparse.ArgumentParser(
      formatter_class=argparse.RawDescriptionHelpFormatter,
      parents=[tools.argparser])
  flags = parser.parse_args([])

  
  flow = client.flow_from_clientsecrets(
      CLIENT_SECRETS_PATH, scope=SCOPES,
      message=tools.message_if_missing(CLIENT_SECRETS_PATH))

  
  storage = file.Storage('analyticsreporting.dat')
  credentials = storage.get()
  if credentials is None or credentials.invalid:
    credentials = tools.run_flow(flow, storage, flags)
  http = credentials.authorize(http=httplib2.Http())

  
  analytics = build('analytics', 'v4', http=http, discoveryServiceUrl=DISCOVERY_URI)

  return analytics

def get_report(analytics):
    
    
  
      return analytics.reports().batchGet(
      body={
        'reportRequests': [
        {
          'viewId': VIEW_ID,
          'pageSize': '1000000',
          'dateRanges': [
            {'startDate' : 'yesterday' ,
             'endDate' : 'yesterday'
            }
          ],
         'metrics': [
              {'expression' : 'ga:pageviews'
              },
              {'expression' : 'ga:uniquePageViews'
              }
         ],
          'dimensions' : [
              
              {'name' : 'ga:pagePath',
              },
              {
               'name' : 'ga:date'
              }
          ],
          'dimensionFilterClauses' : [
              {'filters' : [
                  {'operator' : 'REGEXP', 
                   'dimensionName' : 'ga:pagePath', 
                   'expressions': ['/p/'
                                  ]
                  }
               ]
              }
            ]
          }
        ]
      }
  ).execute()


def convert_to_dataframe(response):
    
  for report in response.get('reports', []):
    columnHeader = report.get('columnHeader', {})
    dimensionHeaders = columnHeader.get('dimensions', [])
    metricHeaders = [i.get('name',{}) for i in columnHeader.get('metricHeader', {}).get('metricHeaderEntries', [])]
    finalRows = []
    

    for row in report.get('data', {}).get('rows', []):
      dimensions = row.get('dimensions', [])
      metrics = row.get('metrics', [])[0].get('values', {})
      rowObject = {}

      for header, dimension in zip(dimensionHeaders, dimensions):
        rowObject[header] = dimension
        
        
      for metricHeader, metric in zip(metricHeaders, metrics):
        rowObject[metricHeader] = metric

      finalRows.append(rowObject)
      
      
  dataFrameFormat = pd.DataFrame(finalRows)    
  return dataFrameFormat      


def main():

  analytics = initialize_analyticsreporting()
  response = get_report(analytics)
  df = convert_to_dataframe(response)  
  df.rename(columns = {'ga:date': 'date','ga:pagePath': 'page_path','ga:pageviews' : 'page_views', 'ga:uniquePageViews' : 'unique_page_views'}, inplace = True)
  df_1 = df['page_path'].str.split("/",n = 4, expand = True)
  df['product_id'] = df_1[3]
  df['date'] = pd.to_datetime(df['date'], dayfirst = True) 
  df['product_id'] = pd.to_numeric(df['product_id'],errors='coerce').fillna(0)
  df['product_id'] = df['product_id'].astype(np.int64)
  df['page_views'] = pd.to_numeric(df['page_views'])
  df['unique_page_views'] = pd.to_numeric(df['unique_page_views']) 
  print(df['date'].dtypes)
  print(df['product_id'].dtypes)
  print(df['page_views'].dtypes)
  print(df['unique_page_views'].dtypes)  
  return df
    
    
if __name__ == '__main__':
  df = main()

engine = sqlalchemy.create_engine("postgresql://doadmin:xpmt05ij9uf9rknn@tjori-bi-do-user-6486966-0.db.ondigitalocean.com:25060/defaultdb", echo = True)
con = engine.connect()
table_name = 'ga_old'
df.to_sql(table_name, con, if_exists = 'append', method = 'multi', chunksize = 10000, index = False)
# Out:
# datetime64[ns]
# int64
# int64
# int64
# 2019-11-18 11:02:13,852 INFO sqlalchemy.engine.base.Engine select version()
# 2019-11-18 11:02:13,852 INFO sqlalchemy.engine.base.Engine {}
# 2019-11-18 11:02:13,966 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2019-11-18 11:02:13,966 INFO sqlalchemy.engine.base.Engine {}
# 2019-11-18 11:02:14,049 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-11-18 11:02:14,049 INFO sqlalchemy.engine.base.Engine {}
# 2019-11-18 11:02:14,095 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-11-18 11:02:14,096 INFO sqlalchemy.engine.base.Engine {}
# 2019-11-18 11:02:14,193 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2019-11-18 11:02:14,194 INFO sqlalchemy.engine.base.Engine {}
# 2019-11-18 11:02:14,296 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-11-18 11:02:14,298 INFO sqlalchemy.engine.base.Engine {'name': 'ga_old'}
# 2019-11-18 11:02:14,342 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-11-18 11:02:14,392 INFO sqlalchemy.engine.base.Engine INSERT INTO ga_old (page_path, date, page_views, unique_page_views, product_id) VALUES (%(page_path_m0)s, %(date_m0)s, %(page_views_m0)s, %(unique_page_views_m0)s, %(product_id_m0)s), (%(page_path_m1)s, %(date_m1)s, %(page_views_m1)s, %(unique_page_views_m1)s, %(product_id_m1)s), (%(page_path_m2)s, %(date_m2)s, %(page_views_m2)s, %(unique_page_views_m2)s, %(product_id_m2)s), (%(page_path_m3)s, %(date_m3)s, %(page_views_m3)s, %(unique_page_views_m3)s, %(product_id_m3)s), (%(page_path_m4)s, %(date_m4)s, %(page_views_m4)s, %(unique_page_views_m4)s, %(product_id_m4)s), (%(page_path_m5)s, %(date_m5)s, %(page_views_m5)s, %(unique_page_views_m5)s, %(product_id_m5)s), (%(page_path_m6)s, %(date_m6)s, %(page_views_m6)s, %(unique_page_views_m6)s, %(product_id_m6)s), (%(page_path_m7)s, %(date_m7)s, %(page_views_m7)s, %(unique_page_views_m7)s, %(product_id_m7)s), (%(page_path_m8)s, %(date_m8)s, %(page_views_m8)s, %(unique_page_views_m8)s, %(product_id_m8)s), (%(page_path_m9)s, %(date_m9)s, %(page_views_m9)s, %(unique_page_views_m9)s, %(product_id_m9)s), (%(page_path_m10)s, %(date_m10)s, %(page_views_m10)s, %(unique_page_views_m10)s, %(product_id_m10)s), (%(page_path_m11)s, %(date_m11)s, %(page_views_m11)s, %(unique_page_views_m11)s, %(product_id_m11)s), (%(page_path_m12)s, %(date_m12)s, %(page_views_m12)s, %(unique_page_views_m12)s, %(product_id_m12)s), (%(page_path_m13)s, %(date_m13)s, %(page_views_m13)s, %(unique_page_views_m13)s, %(product_id_m13)s), (%(page_path_m14)s, %(date_m14)s, %(page_views_m14)s, %(unique_page_views_m14)s, %(product_id_m14)s), (%(page_path_m15)s, %(date_m15)s, %(page_views_m15)s, %(unique_page_views_m15)s, %(product_id_m15)s), (%(page_path_m16)s, %(date_m16)s, %(page_views_m16)s, %(unique_page_views_m16)s, %(product_id_m16)s), (%(page_path_m17)s, %(date_m17)s, %(page_views_m17)s, %(unique_page_views_m17)s, %(product_id_m17)s), (%(page_path_m18)s, %(date_m18)s, %(page_views_m18)s, %(unique_page_views_m18)s, %(product_id_m18)s), (%(page_path_m19)s, %(date_m19)s, %(page_views_m19)s, %(unique_page_views_m19)s, %(product_id_m19)s), (%(page_path_m20)s, %(date_m20)s, %(page_views_m20)s, %(unique_page_views_m20)s, %(product_id_m20)s), (%(page_path_m21)s, %(date_m21)s, %(page_views_m21)s, %(unique_page_views_m21)s, %(product_id_m21)s), (%(page_path_m22)s, %(date_m22)s, %(page_views_m22)s, %(unique_page_views_m22)s, %(product_id_m22)s), (%(page_path_m23)s, %(date_m23)s, %(page_views_m23)s, %(unique_page_views_m23)s, %(product_id_m23)s), (%(page_path_m24)s, %(date_m24)s, %(page_views_m24)s, %(unique_page_views_m24)s, %(product_id_m24)s), (%(page_path_m25)s, %(date_m25)s, %(page_views_m25)s, %(unique_page_views_m25)s, %(product_id_m25)s), (%(page_path_m26)s, %(date_m26)s, %(page_views_m26)s, %(unique_page_views_m26)s, %(product_id_m26)s), (%(page_path_m27)s, %(date_m27)s, %(page_views_m27)s, %(unique_page_views_m27)s, %(product_id_m27)s), (%(page_path_m28)s, %(date_m28)s, %(page_views_m28)s, %(unique_page_views_m28)s, %(product_id_m28)s), (%(page_path_m29)s, %(date_m29)s, %(page_views_m29)s, %(unique_page_views_m29)s, %(product_id_m29)s), (%(page_path_m30)s, %(date_m30)s, %(page_views_m30)s, %(unique_page_views_m30)s, %(product_id_m30)s), (%(page_path_m31)s, %(date_m31)s, %(page_views_m31)s, %(unique_page_views_m31)s, %(product_id_m31)s), (%(page_path_m32)s, %(date_m32)s, %(page_views_m32)s, %(unique_page_views_m32)s, %(product_id_m32)s), (%(page_path_m33)s, %(date_m33)s, %(page_views_m33)s, %(unique_page_views_m33)s, %(product_id_m33)s), (%(page_path_m34)s, %(date_m34)s, %(page_views_m34)s, %(unique_page_views_m34)s, %(product_id_m34)s), (%(page_path_m35)s, %(date_m35)s, %(page_views_m35)s, %(unique_page_views_m35)s, %(product_id_m35)s), (%(page_path_m36)s, %(date_m36)s, %(page_views_m36)s, %(unique_page_views_m36)s, %(product_id_m36)s), (%(page_path_m37)s, %(date_m37)s, %(page_views_m37)s, %(unique_page_views_m37)s, %(product_id_m37)s), (%(page_path_m38)s, %(date_m ...
# 2019-11-18 11:02:14,394 INFO sqlalchemy.engine.base.Engine {'page_path_m0': '/p/207-13/79906/', 'date_m0': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m0': 2, 'unique_page_views_m0': 1, 'product_id_m0': 79906, 'page_path_m1': '/p/207-15/79908/', 'date_m1': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m1': 1, 'unique_page_views_m1': 1, 'product_id_m1': 79908, 'page_path_m2': '/p/207-20/79913/', 'date_m2': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m2': 1, 'unique_page_views_m2': 1, 'product_id_m2': 79913, 'page_path_m3': '/p/207-23/79916/', 'date_m3': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m3': 2, 'unique_page_views_m3': 2, 'product_id_m3': 79916, 'page_path_m4': '/p/207-25/79918/', 'date_m4': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m4': 1, 'unique_page_views_m4': 1, 'product_id_m4': 79918, 'page_path_m5': '/p/207-27/79920/', 'date_m5': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m5': 1, 'unique_page_views_m5': 1, 'product_id_m5': 79920, 'page_path_m6': '/p/207-29/79922/', 'date_m6': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m6': 1, 'unique_page_views_m6': 1, 'product_id_m6': 79922, 'page_path_m7': '/p/207-30/79923/', 'date_m7': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m7': 7, 'unique_page_views_m7': 4, 'product_id_m7': 79923, 'page_path_m8': '/p/207-31/79924/', 'date_m8': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m8': 4, 'unique_page_views_m8': 4, 'product_id_m8': 79924, 'page_path_m9': '/p/207-31/79924/?fbclid=IwAR2csk1r22L_7FtYGBWBLxBdlZPslFBfC5evp2BsANOgIJZ4rknOaM5DDK4', 'date_m9': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m9': 2, 'unique_page_views_m9': 1, 'product_id_m9': 79924, 'page_path_m10': '/p/207-31/79924/?fbclid=IwAR3Ebj-D6DrrOztGgtgA_rmMNJKY8bRTwSVhb2S2feoaIHrd0Cc1trAURdA', 'date_m10': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m10': 1, 'unique_page_views_m10': 1, 'product_id_m10': 79924, 'page_path_m11': '/p/207-32/79925/', 'date_m11': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m11': 1, 'unique_page_views_m11': 1, 'product_id_m11': 79925, 'page_path_m12': '/p/207-32/79925/?fbclid=IwAR0VCWUnVYJ7a_0FOPg7sLQypqZp5TTEosMIKGeRim5j2ixNFPs4uJJpeL8', 'date_m12': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m12': 3, 'unique_page_views_m12': 2, 'product_id_m12': 79925, 'page_path_m13': '/p/207-32/79925/?fbclid=IwAR1qiAA7u-yZvjDmtAL8-3QRz1ZPGY_IsXt12dI4RWRmg2aVvZ-xUjR3c78', 'date_m13': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m13': 3, 'unique_page_views_m13': 2, 'product_id_m13': 79925, 'page_path_m14': '/p/207-35/79928/', 'date_m14': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m14': 5, 'unique_page_views_m14': 5, 'product_id_m14': 79928, 'page_path_m15': '/p/207-35/79928/?fbclid=IwAR0RrjiFVFQhTOCMZ3Il1JDcIAqfXSPexJY5pLGkCQMAhzczwgERTyLkWhM', 'date_m15': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m15': 1, 'unique_page_views_m15': 1, 'product_id_m15': 79928, 'page_path_m16': '/p/207-35/79928/?fbclid=IwAR1WVKhMFU5u0UqelFF-SFQcrcFJe2kUH5YubQE-QSb7V1bCCUHeDI2Gfbw', 'date_m16': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m16': 2, 'unique_page_views_m16': 1, 'product_id_m16': 79928, 'page_path_m17': '/p/207-35/79928/?fbclid=IwAR3XdacXOlIxLrQQqGxxahstGATcXal2-c2j9DMuSmUiax4SAUKewWMurNc', 'date_m17': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m17': 2, 'unique_page_views_m17': 2, 'product_id_m17': 79928, 'page_path_m18': '/p/207-36/79929/', 'date_m18': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m18': 20, 'unique_page_views_m18': 13, 'product_id_m18': 79929, 'page_path_m19': '/p/207-37/79930/', 'date_m19': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m19': 4, 'unique_page_views_m19': 4, 'product_id_m19': 79930, 'page_path_m20': '/p/207-38/79931/?fbclid=IwAR2-MY7ZG4V7ixdfTMdyoShUETjS4KYtHropRHl2CxlenJGLISyDvyA388w', 'date_m20': datetime.datetime(2019, 11, 17, 0, 0), 'page_views_m20': 1, 'unique_page_views_m20': 1, 'product_id_m20': 79931, 'page_path_m21': '/p/207-39/79932/ ...
# 2019-11-18 11:02:14,645 INFO sqlalchemy.engine.base.Engine COMMIT
