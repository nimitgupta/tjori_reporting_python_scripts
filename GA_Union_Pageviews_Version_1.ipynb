# %%
import psycopg2 as pg
import pandas as pd 
import sqlalchemy
import datetime

#Connecting to the database

conn = pg.connect( user = 'doadmin', 
                   password = 'xpmt05ij9uf9rknn', 
                   host = 'tjori-bi-do-user-6486966-0.db.ondigitalocean.com', 
                   port = '25060', 
                   database = 'defaultdb')

#Writing the postgreSQL query to retrieve the data

def retrieve_the_records(yd_1, yd_2):
    sql = '''
             select 
                  *
             from
                  ga_old
             where
                  date = '%s'
                  
             union all
             
             select
                  *
             from 
                  ga_gatsby
             where
                  date = '%s'
             ;
          ''' % (
                 yd_1
                ,yd_2)
    return pd.read_sql_query(sql, conn)

if __name__ == '__main__':
    
    yd = (datetime.datetime.now() - datetime.timedelta(1)).replace(hour=0, minute=0, second=0, microsecond=0).strftime('%Y-%m-%d %H:%M')

def write_the_records():
    df = retrieve_the_records(yd,yd)
    engine = sqlalchemy.create_engine("postgresql://doadmin:xpmt05ij9uf9rknn@tjori-bi-do-user-6486966-0.db.ondigitalocean.com:25060/defaultdb", echo = True)
    con = engine.connect()
    table_name = 'ga_union_pageviews'
    df.to_sql(table_name, con, if_exists = 'append', method = 'multi', chunksize = 10000, index = False)
    
def main():
    while True:
        write_the_records()
        break
        
if __name__ == '__main__':
    main()
# Out:
# 2019-11-18 11:04:00,464 INFO sqlalchemy.engine.base.Engine select version()
# 2019-11-18 11:04:00,469 INFO sqlalchemy.engine.base.Engine {}
# 2019-11-18 11:04:00,564 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2019-11-18 11:04:00,566 INFO sqlalchemy.engine.base.Engine {}
# 2019-11-18 11:04:00,657 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-11-18 11:04:00,659 INFO sqlalchemy.engine.base.Engine {}
# 2019-11-18 11:04:00,711 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-11-18 11:04:00,715 INFO sqlalchemy.engine.base.Engine {}
# 2019-11-18 11:04:00,831 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2019-11-18 11:04:00,833 INFO sqlalchemy.engine.base.Engine {}
# 2019-11-18 11:04:00,930 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-11-18 11:04:00,931 INFO sqlalchemy.engine.base.Engine {'name': 'ga_union_pageviews'}
# 2019-11-18 11:04:00,985 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-11-18 11:04:01,474 INFO sqlalchemy.engine.base.Engine INSERT INTO ga_union_pageviews (date, page_path, page_views, unique_page_views, product_id) VALUES (%(date_m0)s, %(page_path_m0)s, %(page_views_m0)s, %(unique_page_views_m0)s, %(product_id_m0)s), (%(date_m1)s, %(page_path_m1)s, %(page_views_m1)s, %(unique_page_views_m1)s, %(product_id_m1)s), (%(date_m2)s, %(page_path_m2)s, %(page_views_m2)s, %(unique_page_views_m2)s, %(product_id_m2)s), (%(date_m3)s, %(page_path_m3)s, %(page_views_m3)s, %(unique_page_views_m3)s, %(product_id_m3)s), (%(date_m4)s, %(page_path_m4)s, %(page_views_m4)s, %(unique_page_views_m4)s, %(product_id_m4)s), (%(date_m5)s, %(page_path_m5)s, %(page_views_m5)s, %(unique_page_views_m5)s, %(product_id_m5)s), (%(date_m6)s, %(page_path_m6)s, %(page_views_m6)s, %(unique_page_views_m6)s, %(product_id_m6)s), (%(date_m7)s, %(page_path_m7)s, %(page_views_m7)s, %(unique_page_views_m7)s, %(product_id_m7)s), (%(date_m8)s, %(page_path_m8)s, %(page_views_m8)s, %(unique_page_views_m8)s, %(product_id_m8)s), (%(date_m9)s, %(page_path_m9)s, %(page_views_m9)s, %(unique_page_views_m9)s, %(product_id_m9)s), (%(date_m10)s, %(page_path_m10)s, %(page_views_m10)s, %(unique_page_views_m10)s, %(product_id_m10)s), (%(date_m11)s, %(page_path_m11)s, %(page_views_m11)s, %(unique_page_views_m11)s, %(product_id_m11)s), (%(date_m12)s, %(page_path_m12)s, %(page_views_m12)s, %(unique_page_views_m12)s, %(product_id_m12)s), (%(date_m13)s, %(page_path_m13)s, %(page_views_m13)s, %(unique_page_views_m13)s, %(product_id_m13)s), (%(date_m14)s, %(page_path_m14)s, %(page_views_m14)s, %(unique_page_views_m14)s, %(product_id_m14)s), (%(date_m15)s, %(page_path_m15)s, %(page_views_m15)s, %(unique_page_views_m15)s, %(product_id_m15)s), (%(date_m16)s, %(page_path_m16)s, %(page_views_m16)s, %(unique_page_views_m16)s, %(product_id_m16)s), (%(date_m17)s, %(page_path_m17)s, %(page_views_m17)s, %(unique_page_views_m17)s, %(product_id_m17)s), (%(date_m18)s, %(page_path_m18)s, %(page_views_m18)s, %(unique_page_views_m18)s, %(product_id_m18)s), (%(date_m19)s, %(page_path_m19)s, %(page_views_m19)s, %(unique_page_views_m19)s, %(product_id_m19)s), (%(date_m20)s, %(page_path_m20)s, %(page_views_m20)s, %(unique_page_views_m20)s, %(product_id_m20)s), (%(date_m21)s, %(page_path_m21)s, %(page_views_m21)s, %(unique_page_views_m21)s, %(product_id_m21)s), (%(date_m22)s, %(page_path_m22)s, %(page_views_m22)s, %(unique_page_views_m22)s, %(product_id_m22)s), (%(date_m23)s, %(page_path_m23)s, %(page_views_m23)s, %(unique_page_views_m23)s, %(product_id_m23)s), (%(date_m24)s, %(page_path_m24)s, %(page_views_m24)s, %(unique_page_views_m24)s, %(product_id_m24)s), (%(date_m25)s, %(page_path_m25)s, %(page_views_m25)s, %(unique_page_views_m25)s, %(product_id_m25)s), (%(date_m26)s, %(page_path_m26)s, %(page_views_m26)s, %(unique_page_views_m26)s, %(product_id_m26)s), (%(date_m27)s, %(page_path_m27)s, %(page_views_m27)s, %(unique_page_views_m27)s, %(product_id_m27)s), (%(date_m28)s, %(page_path_m28)s, %(page_views_m28)s, %(unique_page_views_m28)s, %(product_id_m28)s), (%(date_m29)s, %(page_path_m29)s, %(page_views_m29)s, %(unique_page_views_m29)s, %(product_id_m29)s), (%(date_m30)s, %(page_path_m30)s, %(page_views_m30)s, %(unique_page_views_m30)s, %(product_id_m30)s), (%(date_m31)s, %(page_path_m31)s, %(page_views_m31)s, %(unique_page_views_m31)s, %(product_id_m31)s), (%(date_m32)s, %(page_path_m32)s, %(page_views_m32)s, %(unique_page_views_m32)s, %(product_id_m32)s), (%(date_m33)s, %(page_path_m33)s, %(page_views_m33)s, %(unique_page_views_m33)s, %(product_id_m33)s), (%(date_m34)s, %(page_path_m34)s, %(page_views_m34)s, %(unique_page_views_m34)s, %(product_id_m34)s), (%(date_m35)s, %(page_path_m35)s, %(page_views_m35)s, %(unique_page_views_m35)s, %(product_id_m35)s), (%(date_m36)s, %(page_path_m36)s, %(page_views_m36)s, %(unique_page_views_m36)s, %(product_id_m36)s), (%(date_m37)s, %(page_path_m37)s, %(page_views_m37)s, %(unique_page_views_m37)s, %(product_id_m37)s), (%(date_m38)s, % ...
# 2019-11-18 11:04:01,485 INFO sqlalchemy.engine.base.Engine {'date_m0': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m0': '/p/after-henna-hair-oil/65047/', 'page_views_m0': 1, 'unique_page_views_m0': 1, 'product_id_m0': 65047, 'date_m1': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m1': '/p/207-30/79923/?fbclid=IwAR2JgtH7PlLp5WvMd49jQdnQFRx47HVZX9hrHIa-kmEGHyzpqEf5IOL9rDI', 'page_views_m1': 1, 'unique_page_views_m1': 1, 'product_id_m1': 79923, 'date_m2': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m2': '/p/100-pure-cotton-pearl-white-charcoal-toda-embroidery-saree/65213/', 'page_views_m2': 4, 'unique_page_views_m2': 4, 'product_id_m2': 65213, 'date_m3': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m3': '/p/100-pure-cotton-pearl-white-charcoal-toda-embroidery-saree/65213/?fbclid=IwAR08S3U0slmoNQb1Ub4Agg219wOEbz7feS5Zz1X_zD1cXxzGqu1YaYH5xaw', 'page_views_m3': 1, 'unique_page_views_m3': 1, 'product_id_m3': 65213, 'date_m4': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m4': '/p/100-pure-jojoba-oil/52764/', 'page_views_m4': 1, 'unique_page_views_m4': 1, 'product_id_m4': 52764, 'date_m5': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m5': '/p/100-pure-mamra-almond-oil-net-weight-338-oz-100-ml/57635/', 'page_views_m5': 2, 'unique_page_views_m5': 2, 'product_id_m5': 57635, 'date_m6': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m6': '/p/2-piece-set-blue-handblocked-cotton-cushion-covers/65909/', 'page_views_m6': 1, 'unique_page_views_m6': 1, 'product_id_m6': 65909, 'date_m7': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m7': '/p/2-piece-set-blue-handblocked-cotton-pillow-cases/65908/', 'page_views_m7': 1, 'unique_page_views_m7': 1, 'product_id_m7': 65908, 'date_m8': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m8': '/p/2-piece-set-indigo-ajrakh-cotton-pillow-covers/65814/', 'page_views_m8': 1, 'unique_page_views_m8': 1, 'product_id_m8': 65814, 'date_m9': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m9': '/p/207-12/79905/', 'page_views_m9': 25, 'unique_page_views_m9': 20, 'product_id_m9': 79905, 'date_m10': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m10': '/p/207-12/79905/?+Beauty+Prod+Users+-+Copy=', 'page_views_m10': 1, 'unique_page_views_m10': 1, 'product_id_m10': 79905, 'date_m11': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m11': '/p/207-12/79905/?+Music+Awards-+Catalog+Sales=', 'page_views_m11': 1, 'unique_page_views_m11': 1, 'product_id_m11': 79905, 'date_m12': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m12': '/p/207-12/79905/?fbclid=IwAR3gcGl_kwCX7wi-GJWyiTzqlfJdCQBvuGQ0oM9HLH0ljqEfjv0MLOULeT4', 'page_views_m12': 1, 'unique_page_views_m12': 1, 'product_id_m12': 79905, 'date_m13': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m13': '/p/207-12/79905/?fbclid=IwAR3lwOvkg6UQzRjsJ5PdRgEs8KkoSQtzGGRTVF4TG4U9tTbtLv7lizuQVUE', 'page_views_m13': 3, 'unique_page_views_m13': 1, 'product_id_m13': 79905, 'date_m14': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m14': '/p/207-13/79906/', 'page_views_m14': 13, 'unique_page_views_m14': 12, 'product_id_m14': 79906, 'date_m15': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m15': '/p/207-15/79908/', 'page_views_m15': 16, 'unique_page_views_m15': 12, 'product_id_m15': 79908, 'date_m16': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m16': '/p/207-18/79911/', 'page_views_m16': 48, 'unique_page_views_m16': 44, 'product_id_m16': 79911, 'date_m17': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m17': '/p/207-18/79911/?fbclid=IwAR15k4SOB2RnGecbpWF-4xbllmCSdAWb_rJKBILF2B2UsnE07k3rVJsdGWs', 'page_views_m17': 2, 'unique_page_views_m17': 1, 'product_id_m17': 79911, 'date_m18': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m18': '/p/207-18/79911/?fbclid=IwAR1yt2dwePlnPLnKB0jclcUAMhzYzBjXYvIjsIB4uWGAtRyIRIjz3gMyOOw', 'page_views_m18': 1, 'unique_page_views_m18': 1, 'product_id_m18': 79911, 'date_m19': datetime.datetime(2019, 11, 17, 0, 0), 'page_path_m19': '/p/207-18/79911/?fbclid=IwAR32gsG3eRH1Zo3yIfgBXZdnQQlYgQCGvdGfc ...
# 2019-11-18 11:04:02,453 INFO sqlalchemy.engine.base.Engine COMMIT
